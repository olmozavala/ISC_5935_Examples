# %%
import matplotlib.pyplot as plt
import numpy as np
from pyecg import ECGRecord
from os.path import join
import os

# %%
## Reading available files
hea_path = "./Data" # If running with F6
# hea_path = "./FileFormats/ECG/Data" # If running from console (pycharm)
files = [x for x in os.listdir(hea_path) if x.find(".hea") != -1]
print(files)
# Out:
# ['214.hea', '208.hea', '210.hea', '202.hea', '205.hea', '201.hea', '209.hea', '212.hea', '207.hea', '213.hea', '200.hea', '203.hea']

# %%
## Reading specific file as a ECGRecord object
c_file = files[0]
print(c_file)
record = ECGRecord.from_wfdb(join(hea_path, c_file))
print(f"Record type: {type(record)}")
print(f"Methods: {vars(record)}")
# Out:
# 214.hea
# Record type: <class 'pyecg.ecg.ECGRecord'>
# Methods: {'record_name': '214', 'time': <pyecg.sequence_data.Time object at 0x7f8de3d351d0>, '_signal_loaders': [<pyecg.ecg.RecordSignalLoader object at 0x7f8de3cd2490>, <pyecg.ecg.RecordSignalLoader object at 0x7f8de3db5e10>], '_record_loader': <pyecg.importers.wfdb.WFDBRecordLoader object at 0x7f8de3e14dd0>, '_annotation_loader': <pyecg.importers.wfdb.WFDBAnnotationLoader object at 0x7f8de3e14210>}

# %%
## Reading the signals
fig, axs = plt.subplots(1,1)
signals = record.signals
# axs.plot(signals[0])
axs.plot(signals[0][0:500])
plt.show()

# %% [markdown]
# Reading annotations

# %%
print(record.annotations._labels)
# Out:
# [+ @ 19, L @ 58, L @ 346, L @ 660, L @ 975, L @ 1290, L @ 1607, L @ 1905, V @ 2135, L @ 2479, L @ 2757, L @ 3073, V @ 3235, L @ 3694, L @ 3972, L @ 4231, L @ 4494, L @ 4767, L @ 5042, L @ 5321, L @ 5638, L @ 5960, L @ 6229, L @ 6489, L @ 6751, L @ 7032, L @ 7326, L @ 7621, L @ 7910, L @ 8210, L @ 8486, L @ 8743, L @ 9012, L @ 9293, L @ 9590, L @ 9900, L @ 10197, L @ 10473, L @ 10751, L @ 11018, L @ 11289, L @ 11571, L @ 11864, L @ 12167, L @ 12464, V @ 12666, L @ 13004, L @ 13273, L @ 13556, L @ 13839, L @ 14130, L @ 14427, L @ 14714, L @ 14993, L @ 15263, L @ 15528, L @ 15822, L @ 16130, L @ 16434, L @ 16731, L @ 17008, L @ 17278, L @ 17541, L @ 17810, L @ 18085, L @ 18390, L @ 18695, L @ 18988, L @ 19270, L @ 19542, L @ 19827, L @ 20117, L @ 20409, L @ 20706, L @ 21013, L @ 21288, L @ 21548, L @ 21809, L @ 22078, L @ 22373, L @ 22679, L @ 22977, L @ 23259, L @ 23534, L @ 23792, L @ 24044, L @ 24312, L @ 24591, L @ 24897, L @ 25261, L @ 25544, L @ 25807, L @ 26080, L @ 26347, L @ 26617, L @ 26900, L @ 27192, L @ 27496, ~ @ 27619, L @ 27778, ~ @ 27869, L @ 28035, + @ 28113, V @ 28191, L @ 28573, L @ 28858, V @ 29079, ~ @ 29231, L @ 29436, L @ 29714, ~ @ 29808, V @ 29866, L @ 30234, L @ 30478, V @ 30645, L @ 31003, L @ 31291, V @ 31486, + @ 31665, L @ 31844, L @ 32094, L @ 32332, L @ 32567, L @ 32813, L @ 33068, L @ 33328, V @ 33538, L @ 33957, L @ 34218, L @ 34479, L @ 34741, L @ 35021, L @ 35304, L @ 